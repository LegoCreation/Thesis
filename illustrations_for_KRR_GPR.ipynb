# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.kernel_ridge import KernelRidge

# Generate some data
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y += 0.5 * np.random.randn(80)

# Define a linear kernel function
def linear_kernel(x1, x2):
    return np.dot(x1, x2.T)

# Define a polynomial kernel function
def polynomial_kernel(x1, x2, d):
    return (1 + np.dot(x1, x2.T)) ** d

# Create a range of alpha values to test
alphas = np.logspace(-5, 2, 200)

# Create a range of degree values for the polynomial kernel
degrees = np.arange(1, 11)

# Initialize arrays to store results
mse_linear = np.zeros_like(alphas)
mse_polynomial = np.zeros((len(alphas), len(degrees)))

# Perform kernel ridge regression with linear kernel
for i, alpha in enumerate(alphas):
    kr = KernelRidge(kernel=linear_kernel, alpha=alpha)
    kr.fit(X, y)
    y_pred = kr.predict(X)
    mse_linear[i] = np.mean((y_pred - y) ** 2)

# Perform kernel ridge regression with polynomial kernel
for i, alpha in enumerate(alphas):
    for j, degree in enumerate(degrees):
        kr = KernelRidge(kernel=lambda x1, x2: polynomial_kernel(x1, x2, degree), alpha=alpha)
        kr.fit(X, y)
        y_pred = kr.predict(X)
        mse_polynomial[i, j] = np.mean((y_pred - y) ** 2)
# Out:
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.22091e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# ...

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot MSE vs. alpha for the linear kernel
axs[0].plot(alphas, mse_linear, label='Linear kernel')
axs[0].set_xscale('log')
axs[0].set_xlabel('Alpha')
axs[0].set_ylabel('MSE')
axs[0].set_title('Kernel Ridge Regression with Linear Kernel')
axs[0].legend()

# Plot MSE vs. alpha for the polynomial kernel
for j, degree in enumerate(degrees):
    axs[1].plot(alphas, mse_polynomial[:, j], label=f'Degree {degree}')
axs[1].set_xscale('log')
axs[1].set_xlabel('Alpha')
axs[1].set_ylabel('MSE')
axs[1].set_title('Kernel Ridge Regression with Polynomial Kernel')
axs[1].legend()

# Add scatter plot of original data and predicted values for all polynomial degrees
fig, axs = plt.subplots(2, 5, figsize=(15, 8))

for j, degree in enumerate(degrees):
    row = j // 5
    col = j % 5

    # Plot original data
    axs[row, col].scatter(X, y, c='k', label='Data')

    # Plot predicted values for polynomial kernel
    alpha = 0.01
    kr = KernelRidge(kernel=lambda x1, x2: polynomial_kernel(x1, x2, degree), alpha=alpha)
    kr.fit(X, y)
    y_pred = kr.predict(X)
    axs[row, col].plot(X, y_pred, c='r', label=f'Degree {degree}')
fig.
# Out:
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=9.7564e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# /home/ssunar/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:196: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot original data
axs[0].scatter(X, y, c='k', label='Data')

# Plot predicted values for linear kernel
alpha = 0.01
kr = KernelRidge(kernel=linear_kernel, alpha=alpha)
kr.fit(X, y)
y_pred = kr.predict(X)
axs[0].plot(X, y_pred, c='r', label='Linear kernel')
axs[0].set_xlabel('X')
axs[0].set_ylabel('y')
axs[0].set_title(f'Kernel Ridge Regression with Linear Kernel, alpha={alpha:.2f}')
axs[0].legend()
